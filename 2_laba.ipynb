# %% [markdown]
# ## Домашняя работа. Pandas
#
# 1. Скачайте этот ноутбук к себе.
# 2. Заполните пропущенные ячейки, отвечая на заданные вопросы. Там должен быть код! (если не сказано обратное)
# 3. Сохраните результат в своём гитхаб репозитории.
#
# #### Полезная литература
#
# - http://pandas.pydata.org/pandas-docs/stable/10min.html
# - https://pandas.pydata.org/pandas-docs/stable/indexing.html
# - https://pandas.pydata.org/pandas-docs/stable/missing_data.html

# %% [markdown]
# В этом задании мы с вами рассмотрим датасет [Adult Data Set](https://archive.ics.uci.edu/ml/datasets/Adult).
# Основывается он на данных переписи населения 1994 года в США.
#
# Расшифровка содержимого колонок:
#
# - age: continuous.
# - workclass: Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked.
# - fnlwgt: continuous. sampling weight, more here: SIPP Weighting.
# - education: Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool.
# - education-num: continuous.
# - marital-status: Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse.
# - occupation: Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces.
# - relationship: Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried.
# - race: White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other, Black.
# - sex: Female, Male.
# - capital-gain: continuous. Income from investment sources, apart from wages/salary.
# - capital-loss: continuous. Losses from investment sources, apart from wages/salary.
# - hours-per-week: continuous.
# - native-country: United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru, Hong, Holand-Netherlands.
# - income: Target feature. Binary.	Income >50K, <=50K.

# %%
import pandas as pd
pd.__version__ # 1.4.1
# Out:
# '2.2.2'

# %%
columns='age,workclass,fnlwgt,education,education-num,marital-status,occupation,relationship,race,sex,capital-gain,capital-loss,hours-per-week,native-country,income'.split(',')
df = pd.read_csv('data/adult.csv.gz', na_values='?') # можно загрузить из файла или URL
# df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data', na_values='?', names=columns)
df.head()
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 0   90       NaN   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66       NaN  186061  Some-college             10        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 0                NaN  Not-in-family  White  Female             0
# 1    Exec-managerial  Not-in-family  White  Female             0
# 2                NaN      Unmarried  Black  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
#
#    capital.loss  hours.per.week native.country income
# 0          4356              40  United-States  <=50K
# ...

# %% [markdown]
# 1) Выведите последние 10 элеметнов датасета

# %%
last_rows = df.tail(10)
last_rows
# Out:
#        age      workclass  fnlwgt      education  education-num  \
# 32551   32        Private   34066           10th              6
# 32552   43        Private   84661      Assoc-voc             11
# 32553   32        Private  116138        Masters             14
# 32554   53        Private  321865        Masters             14
# 32555   22        Private  310152   Some-college             10
# 32556   27        Private  257302     Assoc-acdm             12
# 32557   40        Private  154374        HS-grad              9
# 32558   58        Private  151910        HS-grad              9
# 32559   22        Private  201490        HS-grad              9
# 32560   52   Self-emp-inc  287927        HS-grad              9
#
#             marital-status          occupation    relationship  \
# 32551   Married-civ-spouse   Handlers-cleaners         Husband
# 32552   Married-civ-spouse               Sales         Husband
# 32553        Never-married        Tech-support   Not-in-family
# ...

# %% [markdown]
# 2) Сколько колонок и сколько строк в этом датасете?

# %%
rows_count = df.shape[0]

num_columns = df.shape[1]
print(rows_count)
num_columns
# Out:
# 32561
# 19

# %% [markdown]
# 3) Какие типы данных у элементов этого датасета?

# %%
print(df.dtypes)
# Out:
# age                             int64
# workclass                      object
# fnlwgt                          int64
# education                      object
# education-num                   int64
# marital-status                 object
# occupation                     object
# relationship                   object
# race                           object
# sex                            object
# capital-gain                    int64
# capital-loss                    int64
# hours-per-week                  int64
# native-country                 object
# income                         object
# magic_salary                    int64
# hourly_wage                   float64
# capital_gain_loss               int64
# capital_gain_loss_category      int64
# dtype: object

# %% [markdown]
# 4) Какие признаки имеют пропуски?

# %%
missing_values = df.isnull().sum()
missing_columns = missing_values[missing_values > 0]
print(missing_columns)
# Out:
# Series([], dtype: int64)

# %% [markdown]
# 5) Как вы думаете, с чем связаны пропуски этих значение. Напишите развернутый ответ в ячейке ниже.

# %% [markdown]
# Ваш ответ: Ошибки в процессе сбора данных, некорректный ввод

# %% [markdown]
# 6) Какие и сколько различных рабочих классов workclass представлено в выборке?

# %%
unique_workclasses = df['workclass'].unique()
num_unique_workclasses = len(unique_workclasses)

# Вывод результата
print(f"Количество уникальных рабочих классов: {num_unique_workclasses}")
print("Рабочие классы:", unique_workclasses)
# Out:
# Количество уникальных рабочих классов: 9
# Рабочие классы: [' State-gov' ' Self-emp-not-inc' ' Private' ' Federal-gov' ' Local-gov'
#  ' ?' ' Self-emp-inc' ' Without-pay' ' Never-worked']

# %% [markdown]
# 7) Какой средний возраст женщин и мужчин?

# %%
df['sex'] = df['sex'].str.strip()
print(df['age'].isnull().sum())
print(df['sex'].unique())
# Фильтрация данных по полу
average_age_women = df[df['sex'] == 'Female']['age'].mean()
average_age_men = df[df['sex'] == 'Male']['age'].mean()

# Вывод результатов
print(f"Средний возраст женщин: {average_age_women:.2f} лет")
print(f"Средний возраст мужчин: {average_age_men:.2f} лет")
# Out:
# 0
# ['Male' 'Female']
# Средний возраст женщин: 36.86 лет
# Средний возраст мужчин: 39.43 лет

# %% [markdown]
# 8) Постройте гистограмму(bar) распределения образования людей (education)

# %%
import matplotlib.pyplot as plt

# Проверим уникальные значения в столбце 'education', чтобы убедиться в корректности данных
print(df['education'].unique())

# Подсчитаем количество людей с каждым уровнем образования
education_counts = df['education'].value_counts()

# Построим гистограмму
plt.figure(figsize=(10, 6))
education_counts.plot(kind='bar', color='skyblue')

# Добавим подписи и заголовок
plt.title('Распределение уровня образования людей')
plt.xlabel('Уровень образования')
plt.ylabel('Количество людей')

# Повернем метки на оси X для лучшей читаемости
plt.xticks(rotation=45, ha='right')

# Покажем график
plt.tight_layout()
plt.show()
# Out:
# [' Bachelors' ' HS-grad' ' 11th' ' Masters' ' 9th' ' Some-college'
#  ' Assoc-acdm' ' Assoc-voc' ' 7th-8th' ' Doctorate' ' Prof-school'
#  ' 5th-6th' ' 10th' ' 1st-4th' ' Preschool' ' 12th']

# %% [markdown]
# 9) Каковы средние значения и среднеквадратичные отклонения возраста тех, кто получает более 50K в год (признак salary) и тех, кто получает менее 50K в год?

# %%
# Убираем лишние пробелы из значений в столбце sex

print(df['income'].unique())  # Показать все уникальные значения в столбце income
df['income'] = df['income'].str.strip()

high_income = df[df['income'] == '>50K']
low_income = df[df['income'] == '<=50K']

# Вычисляем средние значения и стандартные отклонения возраста
mean_age_high_income = high_income['age'].mean()
std_age_high_income = high_income['age'].std()

mean_age_low_income = low_income['age'].mean()
std_age_low_income = low_income['age'].std()

# Выводим результаты
print(f"Средний возраст людей с доходом > 50K: {mean_age_high_income:.2f} лет")
print(f"Среднеквадратичное отклонение возраста людей с доходом > 50K: {std_age_high_income:.2f} лет")

print(f"Средний возраст людей с доходом <= 50K: {mean_age_low_income:.2f} лет")
print(f"Среднеквадратичное отклонение возраста людей с доходом <= 50K: {std_age_low_income:.2f} лет")
# Out:
# ['<=50K' '>50K']
# Средний возраст людей с доходом > 50K: 44.25 лет
# Среднеквадратичное отклонение возраста людей с доходом > 50K: 10.52 лет
# Средний возраст людей с доходом <= 50K: 36.78 лет
# Среднеквадратичное отклонение возраста людей с доходом <= 50K: 14.02 лет

# %% [markdown]
# 10) Правда ли, что люди, которые получают больше 50k, имеют как минимум высшее образование? (признак education - Bachelors, Prof-school, Assoc-acdm, Assoc-voc, Masters или Doctorate)

# %%
# Список категорий для высшего образования
higher_education = ['Bachelors', 'Prof-school', 'Assoc-acdm', 'Assoc-voc', 'Masters', 'Doctorate']

# Фильтруем людей с доходом >50K
high_income = df[df['income'] == '>50K']

# Проверяем, все ли значения education входят в список higher_education
all_have_higher_education = high_income['education'].isin(higher_education).all()

# Выводим результат
if all_have_higher_education:
    print("Да, все люди с доходом >50K имеют как минимум высшее образование.")
else:
    print("Нет, среди людей с доходом >50K есть те, кто не имеет высшего образования.")
# Out:
# Нет, среди людей с доходом >50K есть те, кто не имеет высшего образования.

# %% [markdown]
# 11) Среди кого больше доля зарабатывающих много (>50K): среди женатых или холостых мужчин (признак marital-status)? Женатыми считаем тех, у кого marital-status начинается с Married (Married-civ-spouse, Married-spouse-absent или Married-AF-spouse), остальных считаем холостыми.

# %%
# Удаляем лишние пробелы из столбцов 'sex' и 'marital-status'
df['sex'] = df['sex'].str.strip()
df['marital-status'] = df['marital-status'].str.strip()
df['income'] = df['income'].str.strip()

# Фильтруем мужчин
men = df[df['sex'] == 'Male']

# Делим мужчин на женатых и холостых
married_statuses = ['Married-civ-spouse', 'Married-spouse-absent', 'Married-AF-spouse']
married_men = men[men['marital-status'].isin(married_statuses)]
single_men = men[~men['marital-status'].isin(married_statuses)]

# Проверяем, чтобы группы не были пустыми
if married_men.shape[0] > 0 and single_men.shape[0] > 0:
    # Рассчитываем долю зарабатывающих >50K среди каждой группы
    married_men_high_income_ratio = married_men[married_men['income'] == '>50K'].shape[0] / married_men.shape[0]
    single_men_high_income_ratio = single_men[single_men['income'] == '>50K'].shape[0] / single_men.shape[0]

    # Вывод результатов
    print(f"Доля зарабатывающих >50K среди женатых мужчин: {married_men_high_income_ratio:.2%}")
    print(f"Доля зарабатывающих >50K среди холостых мужчин: {single_men_high_income_ratio:.2%}")

    if married_men_high_income_ratio > single_men_high_income_ratio:
        print("Среди женатых мужчин больше доля зарабатывающих >50K.")
    else:
        print("Среди холостых мужчин больше доля зарабатывающих >50K.")
else:
    print("Одна из групп (женатые или холостые мужчины) пуста. Проверьте данные.")
# Out:
# Доля зарабатывающих >50K среди женатых мужчин: 44.05%
# Доля зарабатывающих >50K среди холостых мужчин: 8.45%
# Среди женатых мужчин больше доля зарабатывающих >50K.

# %% [markdown]
# 12) Посчитайте среднее время работы (hours-per-week) зарабатывающих мало и много (salary) для каждой страны (native-country).

# %%
# Удаляем пробелы из строковых столбцов
df['native-country'] = df['native-country'].str.strip()
df['income'] = df['income'].str.strip()

# Разделяем данные на группы по income
high_income = df[df['income'] == '>50K']
low_income = df[df['income'] == '<=50K']

# Группируем по стране и вычисляем среднее значение рабочих часов для каждой группы
high_income_avg_hours = high_income.groupby('native-country')['hours-per-week'].mean()
low_income_avg_hours = low_income.groupby('native-country')['hours-per-week'].mean()

# Выводим результаты
print("Среднее количество рабочих часов зарабатывающих >50K:")
print(high_income_avg_hours)
print("\nСреднее количество рабочих часов зарабатывающих <=50K:")
print(low_income_avg_hours)
# Out:
# Среднее количество рабочих часов зарабатывающих >50K:
# native-country
# ?                     45.547945
# Cambodia              40.000000
# Canada                45.641026
# China                 38.900000
# Columbia              50.000000
# Cuba                  42.440000
# Dominican-Republic    47.000000
# Ecuador               48.750000
# El-Salvador           45.000000
# England               44.533333
# France                50.750000
# Germany               44.977273
# Greece                50.625000
# Guatemala             36.666667
# Haiti                 42.750000
# Honduras              60.000000
# Hong                  45.000000
# Hungary               50.000000
# India                 46.475000
# Iran                  47.500000
# Ireland               48.000000
# Italy                 45.400000
# Jamaica               41.100000
# Japan                 47.958333
# Laos                  40.000000
# Mexico                46.575758
# Nicaragua             37.500000
# ...

# %% [markdown]
# 13) Постройте сводную таблицу для сравнения уровня образования и разницы между capital.gain и capital.loss (то есть пассивный доход). Сделайте так, чтобы capital.gain - capital.loss создали не больше 10 разных уникальных значений. То есть, gain и loss - это числа в каком-то диапазоне. Это количественные признаки из вещественных чисел. С помощью математических функций, типа log, извлечение корня N-ой степени и округления можно перейти к категориальным признакам.

# %%
df.columns = df.columns.str.strip()

# Рассчитываем разницу между capital-gain и capital-loss
df['capital_gain_loss'] = df['capital-gain'] - df['capital-loss']

# Преобразуем разницу в категории (логарифмирование и разбивка на 10 групп)
df['capital_gain_loss_category'] = np.log1p(df['capital_gain_loss'].abs())
df['capital_gain_loss_category'] = pd.cut(df['capital_gain_loss_category'], bins=10, labels=False)

# Создаем сводную таблицу
pivot_table = pd.pivot_table(
    df,
    values='capital_gain_loss',
    index='education',
    columns='capital_gain_loss_category',
    aggfunc=np.mean,
    fill_value=0
)

# Выводим сводную таблицу
print("Сводная таблица:")
print(pivot_table)
# Out:
# Сводная таблица:
# capital_gain_loss_category    0      4           5            6            7  \
# education
# 10th                        0.0  -20.5  594.000000  -165.777778  4190.000000
# 11th                        0.0    0.0  238.714286  -573.130435  5622.827586
# 12th                        0.0    0.0  594.000000  -207.285714  6159.900000
# 1st-4th                     0.0    0.0    0.000000 -1211.400000  4771.250000
# 5th-6th                     0.0    0.0    0.000000  -752.000000  5324.333333
# 7th-8th                     0.0    0.0 -974.000000   519.478261  4700.937500
# 9th                         0.0  114.0  294.333333   898.000000  4152.111111
# Assoc-acdm                  0.0    0.0 -880.000000  -704.083333  6211.720930
# Assoc-voc                   0.0    0.0 -102.750000  -307.762500  5813.426829
# Bachelors                   0.0 -213.0   52.571429 -1090.330049  6536.836478
# Doctorate                   0.0    0.0  594.000000 -1831.185185  5986.115385
# ...

# %% [markdown]
# 14) Женщины из каких стран получают в среднем большую зарплату (>50K) чаще.

# %%
# Удаляем пробелы из названий столбцов
df.columns = df.columns.str.strip()

# Фильтруем данные для женщин
women = df[df['sex'] == 'Female']

# Вычисляем долю женщин с зарплатой >50K для каждой страны
country_high_income = (
    women.groupby('native-country')['income']
    .apply(lambda x: (x == '>50K').mean())
    .sort_values(ascending=False)
)

# Выводим топ стран с наибольшей долей женщин с зарплатой >50K
print("Доля женщин с зарплатой >50K по странам:")
print(country_high_income)
# Out:
# Доля женщин с зарплатой >50K по странам:
# Series([], Name: income, dtype: object)

# %% [markdown]
# 15) Создайте случайную колонку - magic_salary, которую нужно будет вычислить следующим образом: если зарплата небольшая (<50K), тогда случайно выберите число из диапазона [0,50]. Если зарплата выше 50K тогда из диапазона [51, 200]. Посчитайте среднюю зарплату в час для групп людей с одни уровнем образования на основе нашей случайной колонки magic_salary

# %%
import numpy as np

# Удаляем пробелы из названий столбцов
df.columns = df.columns.str.strip()

# Создаем случайную колонку magic_salary
np.random.seed(42)  # Для воспроизводимости результата
df['magic_salary'] = df['income'].apply(
    lambda x: np.random.randint(0, 51) if x == '<=50K' else np.random.randint(51, 201)
)

# Добавляем колонку с зарплатой в час
df['hourly_wage'] = df['magic_salary'] / df['hours-per-week']

# Группируем по уровню образования и считаем среднюю зарплату в час
avg_hourly_wage_by_education = df.groupby('education')['hourly_wage'].mean().sort_values(ascending=False)

# Выводим результаты
print("Средняя зарплата в час для каждого уровня образования:")
print(avg_hourly_wage_by_education)
# Out:
# Средняя зарплата в час для каждого уровня образования:
# education
# 11th            5.013654
# 10th            4.778734
# 7th-8th         4.409834
# 12th            4.262350
# 9th             4.160396
# Assoc-acdm      4.034893
# Some-college    4.030288
# 1st-4th         3.979191
# Preschool       3.770349
# 5th-6th         3.737628
# Assoc-voc       3.663239
# HS-grad         3.640957
# Doctorate       3.607286
# Masters         3.606658
# Bachelors       3.415212
# Prof-school     3.347012
# Name: hourly_wage, dtype: float64
