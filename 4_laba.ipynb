# %% [markdown]
# # Workshop5. Линейная регрессия. (33 балла)
#
# > Линейная регрессия - это не повод для затяжной депрессии.
#
# 1. Скачайте этот ноутбук к себе.
# 2. Заполните пропущенные ячейки, отвечая на заданные вопросы. Там должен быть код! (если не сказано обратное)
# 3. Сохраните результат в своём гитхаб репозитории.
#
# ### Полезная литература
#
# - [Лекция в рамках проекта deeplay[lab] про линейные модели А.Н.Шевляков](https://youtu.be/n9I5BBBZmRU)
# - [Учебник ML от ШАД — линейные модели](https://ml-handbook.ru/chapters/linear_models/intro)
# - Заметки из курса [Машинное обучение на ФКН ВШЭ](https://github.com/esokolov/ml-course-hse)
#   - [лекция 1](99-extra__ml-course-hse__lecture02-linregr.pdf)
#   - [лекция 2](99-extra__ml-course-hse__lecture03-linregr.pdf)
#   - [лекция 3](99-extra__ml-course-hse__lecture04-linregr.pdf)
# - [Статья про лин.рег. от ODS на habrahabr](https://habr.com/ru/company/ods/blog/323890/)

# %% [markdown]
# ## Данные
#
# Возьмем датасет о стоимости домов: https://www.kaggle.com/c/house-prices-advanced-regression-techniques/data.
#
# Он лежит в `./data/house_prices.csv.gz`

# %% [markdown]
# ```
# SalePrice - the property's sale price in dollars. This is the target variable that you're trying to predict.
# MSSubClass: The building class
# MSZoning: The general zoning classification
# LotFrontage: Linear feet of street connected to property
# LotArea: Lot size in square feet
# Street: Type of road access
# Alley: Type of alley access
# LotShape: General shape of property
# LandContour: Flatness of the property
# Utilities: Type of utilities available
# LotConfig: Lot configuration
# LandSlope: Slope of property
# Neighborhood: Physical locations within Ames city limits
# Condition1: Proximity to main road or railroad
# Condition2: Proximity to main road or railroad (if a second is present)
# BldgType: Type of dwelling
# HouseStyle: Style of dwelling
# OverallQual: Overall material and finish quality
# OverallCond: Overall condition rating
# YearBuilt: Original construction date
# YearRemodAdd: Remodel date
# RoofStyle: Type of roof
# RoofMatl: Roof material
# Exterior1st: Exterior covering on house
# Exterior2nd: Exterior covering on house (if more than one material)
# MasVnrType: Masonry veneer type
# MasVnrArea: Masonry veneer area in square feet
# ExterQual: Exterior material quality
# ExterCond: Present condition of the material on the exterior
# Foundation: Type of foundation
# BsmtQual: Height of the basement
# BsmtCond: General condition of the basement
# BsmtExposure: Walkout or garden level basement walls
# BsmtFinType1: Quality of basement finished area
# BsmtFinSF1: Type 1 finished square feet
# BsmtFinType2: Quality of second finished area (if present)
# BsmtFinSF2: Type 2 finished square feet
# BsmtUnfSF: Unfinished square feet of basement area
# TotalBsmtSF: Total square feet of basement area
# Heating: Type of heating
# HeatingQC: Heating quality and condition
# CentralAir: Central air conditioning
# Electrical: Electrical system
# 1stFlrSF: First Floor square feet
# 2ndFlrSF: Second floor square feet
# LowQualFinSF: Low quality finished square feet (all floors)
# GrLivArea: Above grade (ground) living area square feet
# BsmtFullBath: Basement full bathrooms
# BsmtHalfBath: Basement half bathrooms
# FullBath: Full bathrooms above grade
# HalfBath: Half baths above grade
# Bedroom: Number of bedrooms above basement level
# Kitchen: Number of kitchens
# KitchenQual: Kitchen quality
# TotRmsAbvGrd: Total rooms above grade (does not include bathrooms)
# Functional: Home functionality rating
# Fireplaces: Number of fireplaces
# FireplaceQu: Fireplace quality
# GarageType: Garage location
# GarageYrBlt: Year garage was built
# GarageFinish: Interior finish of the garage
# GarageCars: Size of garage in car capacity
# GarageArea: Size of garage in square feet
# GarageQual: Garage quality
# GarageCond: Garage condition
# PavedDrive: Paved driveway
# WoodDeckSF: Wood deck area in square feet
# OpenPorchSF: Open porch area in square feet
# EnclosedPorch: Enclosed porch area in square feet
# 3SsnPorch: Three season porch area in square feet
# ScreenPorch: Screen porch area in square feet
# PoolArea: Pool area in square feet
# PoolQC: Pool quality
# Fence: Fence quality
# MiscFeature: Miscellaneous feature not covered in other categories
# MiscVal: $Value of miscellaneous feature
# MoSold: Month Sold
# YrSold: Year Sold
# SaleType: Type of sale
# SaleCondition: Condition of sale
# ```

# %% [markdown]
# Целевой переменной будет `SalePrice`. То есть мы будем предсказывать стоимость жилья на основе его характеристик.

# %%
# Импортируем библиотеки для работы с данными и статистикой
import pandas as pd  # Библиотека для работы с таблицами (DataFrame)
import scipy.stats as stats  # Статистические функции из SciPy
import numpy as np  # Работа с массивами и математическими операциями
import seaborn as sns  # Визуализация данных с удобными стилями

# Импортируем библиотеку matplotlib для построения графиков
from matplotlib import pyplot as plt

# Импортируем алгоритмы линейной регрессии из библиотеки sklearn
from sklearn.linear_model import LinearRegression  # Классическая линейная регрессия
from sklearn.linear_model import LassoCV  # Lasso-регрессия с автоматическим подбором коэффициента регуляризации
from sklearn.linear_model import Lasso  # Обычная Lasso-регрессия

# Импортируем инструменты для кросс-валидации и разбиения данных
from sklearn.model_selection import cross_val_score  # Функция для оценки модели с помощью кросс-валидации
from sklearn.model_selection import train_test_split  # Функция для разделения данных на обучающую и тестовую выборки

# %matplotlib inline — специальная команда для Jupyter Notebook/Colab,
# которая позволяет отображать графики matplotlib прямо в ячейке без необходимости вызывать plt.show()
# %matplotlib inline

# %%
# Загружаем данные из CSV-файла, расположенного по указанному URL
df = pd.read_csv(
    'https://github.com/senior-sigan/omsu_ml/raw/refs/heads/master/02_linear_regression/data/house_prices.csv.gz',
    index_col='Id'  # Используем колонку 'Id' в качестве индекса DataFrame
)

# Выводим первые 5 строк DataFrame для ознакомления с данными
df.head()
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave   NaN      Reg
# 2           20       RL         80.0     9600   Pave   NaN      Reg
# 3           60       RL         68.0    11250   Pave   NaN      IR1
# 4           70       RL         60.0     9550   Pave   NaN      IR1
# 5           60       RL         84.0    14260   Pave   NaN      IR1
#
#    LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                  ...
# 1          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 2          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
# 3          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 4          Lvl    AllPub    Corner  ...        0    NaN   NaN         NaN
# 5          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
#
#    MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 1        0      2    2008        WD         Normal     208500
# 2        0      5    2007        WD         Normal     181500
# 3        0      9    2008        WD         Normal     223500
# 4        0      2    2006        WD        Abnorml     140000
# 5        0     12    2008        WD         Normal     250000
#
# [5 rows x 80 columns]

# %%
# Получаем список всех колонок в DataFrame df
df.columns
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street', 'Alley',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
#        'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond',
#        'PavedDrive', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
#        'ScreenPorch', 'PoolArea', 'PoolQC', 'Fence', 'MiscFeature', 'MiscVal',
#        'MoSold', 'YrSold', 'SaleType', 'SaleCondition', 'SalePrice'],
#       dtype='object')

# %% [markdown]
# ## 1.0 Анализ целевого признака (3 балла)
#
# Удостоверимся, что раcпределение целевого признака "хорошее", без странных выбросов. В идеале мы хотим видеть нормальное распределени или достаточно похожее на него, без очень длинных "хвостов" выбросов.
#
# _Почему требуется нормальность распределения: ищите объяснения линейной регресси через алгоритмы максимизации правдоподобия. В итоге, грубо говоря, суть сводится к тому, что с ростом объема выборки, оценка максимального правдоподобия лучше описывает нормальное распределение._
#
# [Коэффициент эксцесса](http://www.machinelearning.ru/wiki/index.php?title=%D0%9A%D0%BE%D1%8D%D1%84%D1%84%D0%B8%D1%86%D0%B8%D0%B5%D0%BD%D1%82_%D1%8D%D0%BA%D1%81%D1%86%D0%B5%D1%81%D1%81%D0%B0) показывает степень остроты пика распределения случайной величины. Для нормального распределения он равен `0`. Если хвосты распределения «тяжелее», а пик более «приплюснутый», чем у нормального распределения, то коэффициент < 0. А если хвосты легкие, то больше 0. В нашем случае должно получиться околов `6.5`.
#
# Задание:
# - Нарисуйте график распределения `SalePrice`, используйте аргумент `fit=scipy.stats.norm`, чтобы нарисовать предполагаемое нормальное распределение. Напечатайте значение коэффициент эксцесса `kurtosis` для этого признака.
# - Нарисуйте график [scipy.stats.probplot](https://docs.scipy.org/doc/scipy-0.14.0/reference/generated/scipy.stats.probplot.html) - он покажет нам реальные квантили выборки и теоретические. По нему можно видеть, на сколько много выьросов и на сколько выборка предсказуема.
# - Что вы можете сказать по поводу выборки основываясь на `probplot`.  [wiki](https://en.wikipedia.org/wiki/Normal_probability_plot)

# %%
# Загружаем датасет с ценами на дома из интернета (файл .gz - сжатый CSV)
df = pd.read_csv(
    'https://github.com/senior-sigan/omsu_ml/raw/refs/heads/master/02_linear_regression/data/house_prices.csv.gz'
)

# Создаем график размером 8x4 дюйма
plt.figure(figsize=(8, 4))

# Строим гистограмму распределения цен на дома с KDE-графиком плотности
# - kde=True добавляет график плотности (Kernel Density Estimation)
# - stat="density" нормализует гистограмму
# - label="KDE" используется для отображения в легенде
sns.histplot(df['SalePrice'], kde=True, stat="density", label="KDE")

# Оценка параметров нормального распределения (математическое ожидание и стандартное отклонение)
mu, std = stats.norm.fit(df['SalePrice'])  # fit() подбирает нормальное распределение

# Определяем границы оси X (xmin, xmax), чтобы построить кривую нормального распределения
xmin, xmax = plt.xlim()

# Создаем массив значений X в диапазоне [xmin, xmax], состоящий из 100 точек
x = np.linspace(xmin, xmax, 100)

# Вычисляем значения плотности нормального распределения (PDF) для каждого X
p = stats.norm.pdf(x, mu, std)

# Добавляем на график кривую нормального распределения
# - 'k' (черный цвет)
# - linewidth=2 (толщина линии 2 пикселя)
# - label="Нормальное распределение" - подпись в легенде
plt.plot(x, p, 'k', linewidth=2, label="Нормальное распределение")

# Добавляем легенду на график
plt.legend()

# Отображаем график
plt.show()

# --- Дополнительный анализ данных ---

# Рассчитываем эксцесс (пиковость распределения)
# - stats.kurtosis(df['SalePrice']) оценивает форму распределения
# - Эксцесс показывает, насколько распределение отличается от нормального:
#   * > 0 — "тяжелохвостое" (больше экстремальных значений)
#   * < 0 — "плоское" (меньше экстремальных значений)
#   * ≈ 0 — близко к нормальному распределению
saleprice_kurtosis = stats.kurtosis(df['SalePrice'])

# %%
# Устанавливаем размер графика: 8 (ширина) на 6 (высота) дюймов
plt.figure(figsize=(8, 6))

# Строим Q-Q (Quantile-Quantile) график для проверки нормальности распределения цен на дома
# - stats.probplot() создает Q-Q график:
#   * df['SalePrice'] — данные (цены на дома)
#   * dist="norm" — сравниваем данные с нормальным распределением
#   * plot=plt — строим график с помощью библиотеки Matplotlib
stats.probplot(df['SalePrice'], dist="norm", plot=plt)

# Отображаем график
plt.show()

# %% [markdown]
# На основе probplot'a можно сделать вывод, что выборка имеет выбросы в правом хвосте, что снижает её предсказуемость.

# %% [markdown]
# ## 1.2 Анализ некоторых зависимостей (3 балла)
#
# У нас очень много разных признаков. Любопытно построить разные графики. Позаботьтесь о красоте и наглядности графиков, сделайте так, чтобы они были большими и их можно было прочесть. Даже подписи на графиках должны быть читаемые!!
#
# Задания: Постройте графики, отражающие зависимости этих признаков:
# - дата постройки дома и его стоимости
# - "качество дома и материалов" и его стоимости
# - площадь дома и стоимость
#
# Hints: Вспомните про boxplot, jointplot, lmplot...

# %%
# Устанавливаем размер графика: ширина 10, высота 6 дюймов
plt.figure(figsize=(10, 6))

# Строим диаграмму рассеяния (scatter plot)
# - data=df → используем данные из DataFrame `df`
# - x="YearBuilt" → на оси X — год постройки дома
# - y="SalePrice" → на оси Y — цена продажи дома
sns.scatterplot(data=df, x="YearBuilt", y="SalePrice")

# Отображаем график
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x="OverallQual", y="SalePrice")
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x="GrLivArea", y="SalePrice")
plt.show()

# %% [markdown]
# ## 1.2 Heatmap (3 балла)
#
# Судя по предыдущим графикам, есть некоторые линейные зависимости. Но строить по графику на каждый признак из 80 штук немного долго и не наглядно. Постройте красивый график корреляции всех признаков. Используйте цвета `RdYlGn`, так будет нагляднее. Не забудьте применить маску, чтобы убрать дублирующую половину матрицы.

# %%
numeric_df = df.select_dtypes(include=[np.number])
correlation_matrix = numeric_df.corr()
mask = np.triu(np.ones_like(correlation_matrix, dtype=bool))
plt.figure(figsize=(6, 6))
sns.heatmap(correlation_matrix, mask=mask, cmap='RdYlGn', annot=False, fmt=".2f", linewidths=.5)
plt.xticks(rotation=60)
plt.show()

# %% [markdown]
# Большая матрица 38x38 ячеек. И мы видим, там есть сильно коррелируемые объекты с нашей целевой переменной.
#
# - Нарисуйте крупно heatmap этих сильно коррелируемых объектов( больше 0.5 по абсолютному значению) и сделайте так, чтобы в каждой ячейке было значение корреляции.
# - Выведите список этих сильно коррелируемых признаков.
# - Желательно сделать heatmap диагональной матрицей, чтобы было красиво (в теории был пример)
#
# Запомним эти признаки!

# %%
high_corr = correlation_matrix[abs(correlation_matrix) > 0.5]
strong_corr_matrix = high_corr.dropna(how='all').dropna(axis=1, how='all')
plt.figure(figsize=(36, 12))
sns.heatmap(
    strong_corr_matrix,
    annot=True,
    fmt='.2f',
    linewidths=0.5,
    square=True,
    annot_kws={"size": 7}
)
plt.xticks(rotation=60)
plt.show()
print("Список сильно коррелируемых признаков:", strong_corr_matrix.columns.tolist())
# Out:
# Список сильно коррелируемых признаков: ['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold', 'SalePrice']

# %% [markdown]
# ## 1.3 Пропущеные данные (3 балла)

# %% [markdown]
# Задание:
#  - Посчитайте общее количество пропущенных данных по каждому признаку
#  - посчитайте долю пропущенных данных выборки
#  - удалите из выборки признаки, доля пропущенных которых больще 10%
#  - пропущенные категориальные заполните словом 'unknown' (у них dtype object)
#  - пропущенные числовые заполните средним (у них dtype float)
#
# Hinst: https://stackoverflow.com/a/38134049/3205200

# %%
missing_values_count = df.isnull().sum()
missing_values_count = missing_values_count[missing_values_count > 0].sort_values(ascending=False)
print("общее количество пропущенных данных по каждому признаку", missing_values_count)
# Out:
# общее количество пропущенных данных по каждому признаку PoolQC          1453
# MiscFeature     1406
# Alley           1369
# Fence           1179
# MasVnrType       872
# FireplaceQu      690
# LotFrontage      259
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# BsmtFinType2      38
# BsmtExposure      38
# BsmtFinType1      37
# BsmtCond          37
# BsmtQual          37
# MasVnrArea         8
# Electrical         1
# dtype: int64

# %%
total_cells = np.product(df.shape)
total_missing = missing_values_count.sum()
missing_percentage = (total_missing / total_cells) * 100
print(f"долю пропущенных данных выборки {missing_percentage:.2f}%")
# Out:
# долю пропущенных данных выборки 6.62%

# %%
threshold = 0.1 * df.shape[0]
columns_to_drop = missing_values_count[missing_values_count > threshold].index.tolist()
df_reduced = df.drop(columns=columns_to_drop)
print("удалённые из выборки признаки, доля пропущенных которых больще 10%\n", columns_to_drop)
# Out:
# удалённые из выборки признаки, доля пропущенных которых больще 10%
#  ['PoolQC', 'MiscFeature', 'Alley', 'Fence', 'MasVnrType', 'FireplaceQu', 'LotFrontage']

# %%
categorical_cols = df_reduced.select_dtypes(include=['object']).columns
df_reduced[categorical_cols] = df_reduced[categorical_cols].fillna('unknown')
print("пропущенные категориальные заполненные словом 'unknown' (у них dtype object)\n", categorical_cols.tolist())
# Out:
# пропущенные категориальные заполненные словом 'unknown' (у них dtype object)
#  ['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'SaleType', 'SaleCondition']

# %%
numeric_cols = df_reduced.select_dtypes(include=[np.number]).columns
df_reduced[numeric_cols] = df_reduced[numeric_cols].fillna(df_reduced[numeric_cols].mean())
print("пропущенные числовые заполненные средним (у них dtype float)\n", numeric_cols.tolist())
# Out:
# пропущенные числовые заполненные средним (у них dtype float)
#  ['Id', 'MSSubClass', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold', 'SalePrice']

# %% [markdown]
# ## 1.4 Категориальные переменные (1 балл)
#
# На сколько вы помните, линейная регрессия не умеет обрабатывать категориальные признаки, так как ей нужны ЧИСЛА. Но не беда, в pandas есть встроенная функция [get_dummies](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.get_dummies.html).
#
# Задание:
# - сконвертируйте все категориальные признаки(dtype=object) в вектора числовых с помощью get_dummies
# - напечатайте сколько у вас теперь признаков
# - Положите в переменную X все данные из датасета, кроме целевой переменной. Положите в переменную y только целевую переменную.

# %%
df_with_dummies = pd.get_dummies(df_reduced, drop_first=True)
print(f"Количество признаков после конвертации {df_with_dummies.shape[1]}")
target_variable = 'SalePrice'
# Out:
# Количество признаков после конвертации 240

# %%
x = df_with_dummies.drop(columns=[target_variable])
print("Положим в переменную X все данные из датасета, кроме целевой переменной.\n",x.head())
# Out:
# Положим в переменную X все данные из датасета, кроме целевой переменной.
#     Id  MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 0   1          60     8450            7            5       2003          2003
# 1   2          20     9600            6            8       1976          1976
# 2   3          60    11250            7            5       2001          2002
# 3   4          70     9550            7            5       1915          1970
# 4   5          60    14260            8            5       2000          2000
#
#    MasVnrArea  BsmtFinSF1  BsmtFinSF2  ...  SaleType_ConLI  SaleType_ConLw  \
# 0       196.0         706           0  ...           False           False
# 1         0.0         978           0  ...           False           False
# 2       162.0         486           0  ...           False           False
# 3         0.0         216           0  ...           False           False
# 4       350.0         655           0  ...           False           False
#
#    SaleType_New  SaleType_Oth  SaleType_WD  SaleCondition_AdjLand  \
# 0         False         False         True                  False
# 1         False         False         True                  False
# 2         False         False         True                  False
# 3         False         False         True                  False
# 4         False         False         True                  False
#
#    SaleCondition_Alloca  SaleCondition_Family  SaleCondition_Normal  \
# 0                 False                 False                  True
# 1                 False                 False                  True
# 2                 False                 False                  True
# 3                 False                 False                 False
# 4                 False                 False                  True
#
#    SaleCondition_Partial
# 0                  False
# 1                  False
# 2                  False
# 3                  False
# 4                  False
#
# [5 rows x 239 columns]

# %%
y = df_with_dummies[target_variable]
print("Положим в переменную y только целевую переменную.\n",y.head())
# Out:
# Положим в переменную y только целевую переменную.
#  0    208500
# 1    181500
# 2    223500
# 3    140000
# 4    250000
# Name: SalePrice, dtype: int64

# %% [markdown]
# ## 1.5 Переобучение (3 балла)
#
# Обучим обычную модель без регуляризации [sklearn.linear_model.LinearRegression](http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html).
#
# - Выведите все коэффициенты для каждого признака, отсортировав по возрастанию по модулю значения коэффициента. Используйте print и for, иначе jupyter схлопнет вывод numpy массива. Можете округлить коэффициенты до 2 знаков после запятой.
# - Выведите **среднее** ошибки предсказания на 5 фолдах (cv=5) для этой линейной регрессии с помощью функции [sklearn.model_selection.cross_val_score](http://scikit-learn.org/stable/modules/generated/sklearn.model_selection.cross_val_score.html). Укажите `scoring='neg_mean_squared_error'`, чтобы считалась [MSE](http://scikit-learn.org/stable/modules/model_evaluation.html#mean-squared-error)

# %%
model = LinearRegression()
model.fit(x, y)
coefficients = model.coef_
feature_names = x.columns
coef_with_features = sorted(zip(feature_names, coefficients), key=lambda x: abs(x[1]))
print("Коэффициенты признаков:")
for feature, coef in coef_with_features:
    print(f"{feature}: {coef:.2f}")
# Out:
# Коэффициенты признаков:
# MiscVal: 0.17
# LotArea: 0.77
# Id: 1.26
# BsmtUnfSF: -1.82
# OpenPorchSF: 2.35
# EnclosedPorch: 4.48
# BsmtFinSF2: 6.95
# WoodDeckSF: 13.55
# MasVnrArea: 13.64
# 1stFlrSF: 15.17
# CentralAir_Y: -15.98
# MSSubClass: -17.11
# BsmtFinSF1: 17.47
# GarageArea: 18.22
# LowQualFinSF: -19.14
# TotalBsmtSF: 22.59
# ScreenPorch: 28.57
# GarageYrBlt: -31.21
# GrLivArea: 31.29
# 3SsnPorch: 32.22
# PavedDrive_Y: 34.80
# 2ndFlrSF: 35.26
# PoolArea: 84.33
# YearRemodAdd: 102.45
# GarageFinish_Unf: 133.67
# HeatingQC_Fa: -215.75
# Electrical_FuseF: -235.00
# SaleCondition_Family: -289.50
# SaleType_WD: -295.64
# Functional_Maj2: -311.99
# YearBuilt: 318.99
# YrSold: -330.90
# MoSold: -452.28
# BsmtFullBath: 584.30
# BsmtCond_Gd: -600.69
# BsmtFinType1_Rec: -771.69
# HalfBath: 821.75
# BsmtHalfBath: -879.57
# Neighborhood_Blueste: 1070.16
# SaleCondition_Partial: -1117.77
# TotRmsAbvGrd: 1149.78
# SaleType_ConLw: 1264.84
# HouseStyle_SFoyer: 1368.98
# BsmtFinType1_BLQ: 1405.52
# LotShape_Reg: 1502.00
# Neighborhood_BrDale: 1516.78
# Neighborhood_SawyerW: -1520.71
# Electrical_SBrkr: -1679.89
# Condition1_RRNe: -1706.18
# LotConfig_Inside: -1762.76
# Condition2_RRNn: 1812.57
# PavedDrive_P: -1843.88
# HouseStyle_SLvl: 2015.20
# Functional_Mod: -2019.69
# Neighborhood_BrkSide: -2166.83
# Neighborhood_Somerst: 2275.53
# HeatingQC_Po: 2438.27
# ExterCond_Fa: -2558.11
# Fireplaces: 2627.02
# BsmtFinType1_Unf: 2856.66
# GarageFinish_RFn: -2876.38
# BsmtCond_TA: 3013.90
# Foundation_CBlock: 3222.86
# BedroomAbvGr: -3403.92
# FullBath: 3443.93
# BsmtFinType2_GLQ: -3505.15
# HeatingQC_TA: -3589.61
# Neighborhood_MeadowV: -3614.97
# HeatingQC_Gd: -3741.63
# LotShape_IR2: 3766.47
# Neighborhood_Veenker: 3950.77
# BsmtFinType1_LwQ: -3977.64
# ExterCond_TA: -4057.94
# Foundation_PConc: 4101.02
# Condition2_Feedr: -4118.22
# GarageCars: 4217.88
# Exterior1st_BrkFace: 4302.50
# BsmtExposure_Mn: -4416.50
# LotShape_IR3: 5205.97
# BsmtFinType1_GLQ: 5426.33
# Exterior2nd_BrkFace: 5445.82
# RoofStyle_Hip: 5590.04
# HouseStyle_2Story: -5704.46
# OverallCond: 5707.53
# LandContour_Lvl: 5734.19
# ExterCond_Po: 5804.62
# Neighborhood_SWISU: -5824.32
# Heating_Grav: 5824.38
# Condition1_Feedr: 5872.40
# RoofStyle_Gable: 5971.55
# SaleCondition_Normal: 6032.77
# SaleType_ConLI: 6052.29
# BsmtExposure_No: -6082.54
# ExterQual_Fa: -6254.15
# GarageCond_unknown: 6317.13
# GarageFinish_unknown: 6317.13
# GarageQual_unknown: 6317.13
# GarageType_unknown: 6317.13
# SaleCondition_Alloca: 6390.69
# ExterCond_Gd: -6568.88
# Condition1_RRNn: 6643.04
# OverallQual: 6683.27
# Condition2_Norm: -7078.23
# Exterior2nd_Brk Cmn: 7291.22
# Foundation_Stone: 7352.61
# Neighborhood_IDOTRR: -7355.17
# LotConfig_CulDSac: 7366.23
# Neighborhood_CollgCr: -7418.34
# Condition1_RRAn: 7458.64
# Condition1_PosA: 7546.04
# Exterior2nd_Wd Shng: 7551.12
# Heating_GasW: 7590.10
# BldgType_2fmCon: -7647.23
# Exterior1st_Stone: -7675.78
# LandSlope_Mod: 7714.01
# LandContour_HLS: 7904.79
# Neighborhood_Sawyer: -8056.03
# HouseStyle_1Story: 8166.28
# Functional_Min1: 8240.20
# SaleType_Oth: 8250.76
# Neighborhood_Gilbert: -8272.57
# Exterior2nd_Stucco: 8308.86
# SaleCondition_AdjLand: 8351.65
# LotConfig_FR2: -8430.05
# Exterior2nd_MetalSd: 8516.27
# Foundation_Slab: -8584.61
# RoofStyle_Gambrel: 8793.44
# Neighborhood_Timber: -9106.99
# Exterior2nd_Plywood: 9184.33
# Electrical_FuseP: -9218.45
# HouseStyle_2.5Unf: -9740.98
# Exterior1st_Stucco: -10061.53
# Exterior1st_CBlock: -10215.13
# Exterior2nd_CBlock: -10215.13
# Exterior1st_MetalSd: -10609.32
# Exterior2nd_Stone: -10644.30
# BsmtFinType2_Unf: -10726.62
# Exterior2nd_HdBoard: 10807.03
# BldgType_Duplex: -10821.03
# Neighborhood_OldTown: -10974.15
# BsmtFinType2_Rec: -11205.28
# Heating_GasA: 11285.35
# Exterior1st_BrkComm: -11349.19
# Functional_Min2: 11445.63
# LandContour_Low: -12052.74
# Condition1_PosN: 12151.67
# KitchenAbvGr: -12463.70
# Exterior2nd_AsphShn: 12493.65
# Neighborhood_ClearCr: -12648.51
# HouseStyle_1.5Unf: 13002.47
# Heating_OthW: -13302.19
# BsmtQual_unknown: 13306.72
# BsmtFinType1_unknown: 13306.72
# BsmtCond_unknown: 13306.72
# Exterior2nd_Wd Sdng: 13309.99
# Neighborhood_NAmes: -13489.96
# BsmtExposure_Gd: 13494.28
# BsmtFinType2_BLQ: -13574.33
# Exterior1st_WdShing: -13834.38
# BsmtExposure_unknown: -13882.38
# BsmtQual_Fa: -14023.06
# Neighborhood_Crawfor: 14437.82
# Exterior2nd_VinylSd: 14812.32
# Condition1_Norm: 14862.78
# SaleType_CWD: 14971.58
# Exterior2nd_CmentBd: 15223.11
# Neighborhood_NWAmes: -15786.25
# Neighborhood_NPkVill: 15869.60
# Condition1_RRAe: -16049.23
# SaleType_ConLD: 16153.71
# BsmtFinType2_LwQ: -16475.67
# Exterior1st_CemntBd: -16607.43
# BsmtQual_TA: -16742.91
# Electrical_unknown: 16933.02
# Exterior1st_VinylSd: -17133.47
# LotConfig_FR3: -17275.72
# Exterior1st_HdBoard: -17370.86
# Exterior1st_Wd Sdng: -17595.60
# Neighborhood_Edwards: -17689.14
# Exterior2nd_Other: -18123.22
# GarageType_BuiltIn: 18636.25
# KitchenQual_Fa: -18733.58
# RoofStyle_Mansard: 18842.24
# Exterior1st_Plywood: -18852.39
# BldgType_TwnhsE: -19045.89
# BsmtQual_Gd: -19270.64
# Neighborhood_Mitchel: -19568.95
# GarageType_Attchd: 19651.10
# Functional_Typ: 19814.61
# ExterQual_Gd: -20270.82
# ExterQual_TA: -20519.02
# Condition2_RRAn: -20666.63
# Neighborhood_NridgHt: 21307.98
# KitchenQual_TA: -22006.40
# SaleType_New: 22341.39
# BldgType_Twnhs: -22370.58
# GarageType_Basment: 22587.77
# MSZoning_RM: 22777.36
# GarageType_Detchd: 23098.31
# HouseStyle_2.5Fin: -23187.34
# KitchenQual_Gd: -24385.02
# MSZoning_RH: 24881.92
# Heating_Wall: 25705.57
# GarageType_CarPort: 26152.49
# MSZoning_RL: 26354.63
# Utilities_NoSeWa: -26448.66
# Foundation_Wood: -26779.45
# SaleType_Con: 27167.70
# Exterior1st_AsphShn: -27823.14
# Neighborhood_NoRidge: 28480.99
# Exterior2nd_ImStucc: 29849.85
# Street_Pave: 32291.72
# MSZoning_FV: 32594.74
# BsmtFinType2_unknown: -32687.90
# Condition2_PosA: 40365.18
# Neighborhood_StoneBr: 41013.83
# LandSlope_Sev: -42838.37
# Electrical_Mix: -48646.39
# Functional_Sev: -51332.29
# Exterior1st_ImStucc: -52946.82
# BsmtCond_Po: 71542.37
# RoofStyle_Shed: 96434.24
# GarageCond_Gd: 106058.74
# GarageCond_Fa: 106069.37
# GarageCond_TA: 108490.77
# GarageCond_Po: 109240.28
# GarageQual_Gd: -111630.66
# GarageQual_TA: -113013.18
# GarageQual_Fa: -118758.06
# Condition2_RRAe: -126430.97
# GarageQual_Po: -131601.17
# Condition2_PosN: -236656.16
# RoofMatl_WdShake: 658783.81
# RoofMatl_Roll: 659742.77
# RoofMatl_CompShg: 666101.55
# RoofMatl_Tar&Grv: 672170.99
# RoofMatl_WdShngl: 719349.09
# RoofMatl_Metal: 734960.10
# RoofMatl_Membran: 762342.43

# %%
mse_scores = cross_val_score(model, x, y, cv=5, scoring='neg_mean_squared_error')
mean_mse = -mse_scores.mean()
print("Выведим среднее ошибки предсказания на 5 фолдах (cv=5) для этой линейной регрессии", mean_mse)
# Out:
# Выведим среднее ошибки предсказания на 5 фолдах (cv=5) для этой линейной регрессии 2030110765.114303

# %% [markdown]
# К счастью в этот раз коэффициенты при признаках не улетели в космос, но всё равно достигли очень больших значений. Например `RoofStyle_Shed` получился в моем случае около `-514961`. А у некоторых признаков коэффициент уже равен 0, хотя не была применена регуляризация.

# %% [markdown]
# ## 1.6 Ridge и Lasso (4 балла)
#
# - Обучите Lasso и Ridge для разных значений регуляризации alpha
# - нарисуйте график значений коэффициентов модели для каждого признака, как мы делали на практике. По оси X будет значение alpha, по Y - значение коэффициента. на графике будет "радуга" из линий разных цветов(линий столько, сколько признаков).
# - Нарисуйте гистограмму, в которой по оси Y будет количество коэффициентов, равных 0 (<0.0001) для Loss регресиии, а по оси X - значение коэффициента альфа.
#
# alpha взять от 1 до 500 с каким-нибудь шагом. Но не переборщите, а то долго будете ждать.

# %%
from sklearn.linear_model import Lasso, Ridge
from sklearn.impute import SimpleImputer

alphas = range(1, 501, 20)
lasso_coefs = []
ridge_coefs = []

for alpha in alphas:
    lasso = Lasso(alpha=alpha, max_iter=10000)
    lasso.fit(x, y)
    lasso_coefs.append(lasso.coef_)

    ridge = Ridge(alpha=alpha)
    ridge.fit(x, y)
    ridge_coefs.append(ridge.coef_)

lasso_coefs = np.array(lasso_coefs)
ridge_coefs = np.array(ridge_coefs)

plt.figure(figsize=(10, 6))
for i in range(lasso_coefs.shape[1]):
    plt.plot(alphas, lasso_coefs[:, i], label=f'Признак {i}' if i < 10 else "")
plt.xlabel("alpha")
plt.ylabel("значение коэффициента")
plt.title("Lasso график значений коэффициентов модели для каждого признака")
plt.show()

# %%
plt.figure(figsize=(10, 6))
for i in range(ridge_coefs.shape[1]):
    plt.plot(alphas, ridge_coefs[:, i], label=f'Признак {i}' if i < 10 else "")
plt.xlabel("alpha")
plt.ylabel("значение коэффициента")
plt.title("Ridge график значений коэффициентов модели для каждого признака")
plt.show()

# %%
zero_coefs_count = [(np.abs(coef) < 0.0001).sum() for coef in lasso_coefs]

plt.figure(figsize=(10, 6))
plt.bar(alphas, zero_coefs_count, width=10)
plt.xlabel("alpha")
plt.ylabel("количество коэфф, равных 0 (<0.0001) для Loss регресиии")
plt.show()

# %% [markdown]
# ## 1.7 Поиск оптимального alpha (6 баллов)
#
# - С помощью метода LassoCV найдите оптимальное значение alpha и напечатайте его, используя разбиение на 5 фолда в кроссвалидации (`cv=5`).
# - Нарисуйте график зависимости MSE от alpha (`mse_path_`).
# - Нарисуйте длинную гистограмму магнитуда признаков, как в классе, на которой будет показано значение коэффициента для каждого признака. Графк должен быть остортирован по величине коэффициентов. Признаки с нулевыми коэффициентами должны быть удалены.
# - Сколько в итоге ненулевых признаков осталось?
# - Выведите **среднее** ошибки предсказания на 5 фолдах (cv=5) для этой линейной регрессии с помощью функции [sklearn.model_selection.cross_val_score](http://scikit-learn.org/stable/modules/generated/sklearn.model_selection.cross_val_score.html). Укажите `scoring='neg_mean_squared_error'`, чтобы считалась [MSE](http://scikit-learn.org/stable/modules/model_evaluation.html#mean-squared-error). Качество должно быть лучше, чем у простой линейной регрессии.

# %%
lasso_cv = LassoCV(cv=5, random_state=33)
lasso_cv.fit(x, y)

optimal_alpha = lasso_cv.alpha_
print(f"Оптимальное значение alpha: {optimal_alpha}")
# Out:
# Оптимальное значение alpha: 209067.7746829921

# %%
imputer = SimpleImputer(strategy="mean")
x = pd.get_dummies(df.drop(["SalePrice"], axis=1), drop_first=True)
x = pd.DataFrame(imputer.fit_transform(x), columns=x.columns)
y = df['SalePrice']

alphas = np.linspace(1, 500, 200)

lasso = LassoCV(alphas=alphas, random_state=30, cv=5)
lasso.fit(x, y)

print(f"\n\n\nоптимальное значение alpha {lasso.alpha_} \n\n\n")

plt.plot(lasso.alphas_, lasso.mse_path_.mean(axis=1))
plt.xlabel("alpha")
plt.ylabel("mean Squared Error (MSE)")
plt.title("график зависимости MSE от alpha")
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 172698243056.8381, tolerance: 759214014.2531197
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8358995750.932922, tolerance: 728773513.025937
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 132312823585.68973, tolerance: 728773513.025937
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 207569029061.63556, tolerance: 728773513.025937
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 182826041429.0968, tolerance: 699031751.5199751
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 224091460911.54773, tolerance: 699031751.5199751
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 204134200911.86368, tolerance: 699031751.5199751
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1057700823.572998, tolerance: 770619031.1834062
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 21611480525.550293, tolerance: 770619031.1834062
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 250665694927.5159, tolerance: 770619031.1834062
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 185833566196.34198, tolerance: 724930391.3116124
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 232698309835.3295, tolerance: 724930391.3116124
#   model = cd_fast.enet_coordinate_descent_gram(
# оптимальное значение alpha 123.86934673366834

# %%
df_coef = pd.DataFrame(list(zip(lasso.coef_, x.columns)), columns=["coef", "columns"])

df_coef = df_coef[np.abs(df_coef['coef']) >= 0.01]

plt.figure(figsize=(20, 4))
sns.barplot(x="columns", y="coef", data=df_coef.sort_values("coef"))
plt.xticks(rotation=90)
plt.xlabel("Признаки")
plt.ylabel("Значение коэффициента")
plt.title("Значимые коэффициенты модели Lasso")
plt.show()

# %%
lasso_coefs = lasso_cv.coef_
non_zero_coefs = lasso_coefs[lasso_coefs != 0]
num_non_zero_features = len(non_zero_coefs)
plt.figure(figsize=(8, 4))
plt.bar(range(num_non_zero_features), sorted(np.abs(non_zero_coefs)))
plt.xlabel("Признаки")
plt.ylabel("величина коэффициентов")
plt.title("гистограмма магнитуды признаков")
plt.show()
print(f"\n\n\nколичество ненулевых признаков: {num_non_zero_features}")
# Out:
# количество ненулевых признаков: 12

# %%
mse_scores = cross_val_score(lasso_cv, x, y, cv=5, scoring='neg_mean_squared_error')
mean_mse = -mse_scores.mean()
print(f"среднbе ошибки предсказания на 5 фолдах (cv=5) для этой линейной регрессии {mean_mse}")
# Out:
# среднbе ошибки предсказания на 5 фолдах (cv=5) для этой линейной регрессии 1887537311.7597165

# %% [markdown]
# ## 1.8 Предсказание на отложенной выборке (3 балла)
#
# - Используя [sklearn.model_selection.train_test_split](http://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html) разбейте датасет на 2 части - тренировочную и тестовую в соотношении 0.33. Не забудьте перемешать!
# - Напечатайте размерность X_train и X_test

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=12, shuffle=True)
print("Размерность X_train:", X_train.shape)
print("Размерность X_test:", X_test.shape)
# Out:
# Размерность X_train: (978, 245)
# Размерность X_test: (482, 245)

# %% [markdown]
# Теперь, возьмите вашу самую мощную модель(не тренированную!). Запустите её тренировку по тренировочной выборке X_train, y_train с помощью функции `fit`. Постройте предсказания с помощью функции `predict`.

# %%
lasso_model = Lasso(alpha=optimal_alpha)
lasso_model.fit(X_train, y_train)

y_pred = lasso_model.predict(X_test)

# %% [markdown]
# Визуализируйте scatter plot предсказанных значений и настоящих (`y_test`). У вас должен получиться график, точки которого расположены приблизительно вдоль некоторой прямой с разбросом. Идеальный предсказатель будет выглядить как набор точек вдоль прямой без разброса.

# %%
plt.figure(figsize=(16, 4))
plt.scatter(y_test, y_pred, alpha=0.5)
plt.xlabel("настоящие")
plt.ylabel("предсказанные")
plt.title("Сравнение предсказанных и настоящих значений")
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--')  # Линия идеального предсказания
plt.show()

# %% [markdown]
# ## 1.9 Ограниченная версия ( 4 балла)
#
# Помните в самом начале мы оставили очень мало признаков по данным из heatmap. Настало время проверить как он себя покажет! К счастью они все сразу числовые, а не категориальные. Переиспользуйте тот дадасет, где вы уже поборолись с пропусками.
# Снова выделите отдельно X и y и запустите кроссвалидацию c 5 фолдами по Lasso с `alpha=1`.

# %%
important_features = ['OverallQual', 'GrLivArea', 'GarageCars', 'TotalBsmtSF', '1stFlrSF']
df_limited = df_with_dummies[important_features + ['SalePrice']]
X_limited = df_limited.drop(columns=['SalePrice'])
y_limited = df_limited['SalePrice']
lasso_limited = Lasso(alpha=1)
mse_scores_limited = cross_val_score(lasso_limited, X_limited, y_limited, cv=5, scoring='neg_mean_squared_error')
mean_mse_limited = -mse_scores_limited.mean()
print(f"Средняя ошибка предсказания по 5 фолдам: {mean_mse_limited}")
# Out:
# Средняя ошибка предсказания по 5 фолдам: 1572401602.7339535
